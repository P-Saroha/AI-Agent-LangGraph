# %%
from langgraph.graph import StateGraph, START, END
from dotenv import load_dotenv, find_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict

# %%
load_dotenv(find_dotenv())
# Out:
# True

# %%
llm = ChatGoogleGenerativeAI(
            model="gemini-2.5-flash",
            temperature=0.3
              )

# %%
class BlogState(TypedDict):

    title : str
    outline : str
    content : str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = llm.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = llm.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India and consern with AI in india '}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India and consern with AI in india ', 'outline': 'Here\'s a detailed outline for a blog post on the rise and concerns of AI in India, designed to be comprehensive and engaging:\n\n---\n\n## Blog Title Options:\n\n*   **India\'s AI Ascent: Navigating the Promise and Peril of Artificial Intelligence**\n*   **The Dual Edge: How AI is Reshaping India, and What Keeps Us Up at Night**\n*   **From Silicon Valley to Bengaluru: India\'s AI Revolution and Its Unseen Challenges**\n*   **AI in India: A Story of Innovation, Impact, and Impending Questions**\n\n---\n\n## Detailed Blog Outline:\n\n**I. Introduction: The AI Tsunami Reaches Indian Shores**\n\n*   **A. Hook:** Start with a compelling statistic or a vivid image of AI\'s global impact (e.g., "The world is in the throes of an AI revolution, and India is not just a spectator, but a key player...")\n*   **B. Context:** Briefly introduce India\'s unique position – a rapidly digitizing nation with a vast talent pool, ripe for AI adoption.\n*   **C. Thesis Statement:** State the blog\'s purpose – to explore the exciting rise of AI in India, while critically examining the significant concerns and challenges that accompany this technological boom.\n*   **D. Roadmap:** Briefly outline what the reader can expect to learn (the growth, the sectors, the ethical dilemmas, the socio-economic impact).\n\n**II. The Rise of AI in India: A Nation Embracing Innovation**\n\n*   **A. Government Initiatives & Vision:**\n    *   "AI for All": NITI Aayog\'s national strategy and focus areas.\n    *   Digital India program as a foundation for AI adoption.\n    *   Investment in AI research and development (e.g., setting up Centers of Excellence).\n    *   Policy frameworks and regulatory discussions (e.g., data protection bill).\n*   **B. Thriving Startup Ecosystem:**\n    *   Explosion of AI startups across various sectors (FinTech, HealthTech, AgriTech, EdTech).\n    *   Increased venture capital funding and investor interest in Indian AI companies.\n    *   Examples of innovative Indian AI solutions (e.g., vernacular language processing, AI for social good).\n*   **C. Sectoral Impact & Transformation:**\n    *   **Healthcare:** AI-powered diagnostics, drug discovery, personalized medicine, remote patient monitoring.\n    *   **Finance:** Fraud detection, personalized banking, credit scoring, algorithmic trading.\n    *   **Agriculture:** Precision farming, crop yield prediction, pest detection, supply chain optimization.\n    *   **Education:** Personalized learning platforms, intelligent tutoring systems, administrative automation.\n    *   **Manufacturing & Logistics:** Predictive maintenance, quality control, supply chain efficiency, autonomous vehicles.\n    *   **Customer Service:** Chatbots, virtual assistants, sentiment analysis.\n*   **D. India\'s Talent Pool & R&D Prowess:**\n    *   Large base of STEM graduates and IT professionals.\n    *   Growing number of AI researchers and data scientists.\n    *   Contributions from academic institutions and corporate R&D centers.\n    *   India as a global hub for AI development and outsourcing.\n*   **E. Economic Growth & Digital Transformation:**\n    *   Potential for significant GDP contribution from AI.\n    *   Creation of new industries and job roles.\n    *   Enhancing productivity and efficiency across sectors.\n\n**III. The Concerns with AI in India: Navigating the Peril**\n\n*   **A. Job Displacement & The Future of Work:**\n    *   Automation of repetitive tasks leading to job losses in traditional sectors (manufacturing, BPO, data entry).\n    *   The challenge of reskilling and upskilling a massive workforce.\n    *   The potential for increased unemployment and social unrest if not managed proactively.\n*   **B. Ethical AI & Algorithmic Bias:**\n    *   **Data Bias:** AI models trained on unrepresentative or biased Indian datasets leading to unfair outcomes (e.g., in credit scoring, facial recognition, hiring).\n ...

# %%
print(final_state['outline'])
# Out:
# Here's a detailed outline for a blog post on the rise and concerns of AI in India, designed to be comprehensive and engaging:
#
# ---
#
# ## Blog Title Options:
#
# *   **India's AI Ascent: Navigating the Promise and Peril of Artificial Intelligence**
# *   **The Dual Edge: How AI is Reshaping India, and What Keeps Us Up at Night**
# *   **From Silicon Valley to Bengaluru: India's AI Revolution and Its Unseen Challenges**
# *   **AI in India: A Story of Innovation, Impact, and Impending Questions**
#
# ---
#
# ## Detailed Blog Outline:
#
# **I. Introduction: The AI Tsunami Reaches Indian Shores**
#
# *   **A. Hook:** Start with a compelling statistic or a vivid image of AI's global impact (e.g., "The world is in the throes of an AI revolution, and India is not just a spectator, but a key player...")
# *   **B. Context:** Briefly introduce India's unique position – a rapidly digitizing nation with a vast talent pool, ripe for AI adoption.
# *   **C. Thesis Statement:** State the blog's purpose – to explore the exciting rise of AI in India, while critically examining the significant concerns and challenges that accompany this technological boom.
# *   **D. Roadmap:** Briefly outline what the reader can expect to learn (the growth, the sectors, the ethical dilemmas, the socio-economic impact).
#
# **II. The Rise of AI in India: A Nation Embracing Innovation**
#
# *   **A. Government Initiatives & Vision:**
#     *   "AI for All": NITI Aayog's national strategy and focus areas.
#     *   Digital India program as a foundation for AI adoption.
#     *   Investment in AI research and development (e.g., setting up Centers of Excellence).
#     *   Policy frameworks and regulatory discussions (e.g., data protection bill).
# *   **B. Thriving Startup Ecosystem:**
#     *   Explosion of AI startups across various sectors (FinTech, HealthTech, AgriTech, EdTech).
#     *   Increased venture capital funding and investor interest in Indian AI companies.
#     *   Examples of innovative Indian AI solutions (e.g., vernacular language processing, AI for social good).
# *   **C. Sectoral Impact & Transformation:**
#     *   **Healthcare:** AI-powered diagnostics, drug discovery, personalized medicine, remote patient monitoring.
#     *   **Finance:** Fraud detection, personalized banking, credit scoring, algorithmic trading.
#     *   **Agriculture:** Precision farming, crop yield prediction, pest detection, supply chain optimization.
#     *   **Education:** Personalized learning platforms, intelligent tutoring systems, administrative automation.
#     *   **Manufacturing & Logistics:** Predictive maintenance, quality control, supply chain efficiency, autonomous vehicles.
#     *   **Customer Service:** Chatbots, virtual assistants, sentiment analysis.
# *   **D. India's Talent Pool & R&D Prowess:**
#     *   Large base of STEM graduates and IT professionals.
#     *   Growing number of AI researchers and data scientists.
#     *   Contributions from academic institutions and corporate R&D centers.
#     *   India as a global hub for AI development and outsourcing.
# *   **E. Economic Growth & Digital Transformation:**
#     *   Potential for significant GDP contribution from AI.
#     *   Creation of new industries and job roles.
#     *   Enhancing productivity and efficiency across sectors.
#
# **III. The Concerns with AI in India: Navigating the Peril**
#
# *   **A. Job Displacement & The Future of Work:**
#     *   Automation of repetitive tasks leading to job losses in traditional sectors (manufacturing, BPO, data entry).
#     *   The challenge of reskilling and upskilling a massive workforce.
#     *   The potential for increased unemployment and social unrest if not managed proactively.
# *   **B. Ethical AI & Algorithmic Bias:**
#     *   **Data Bias:** AI models trained on unrepresentative or biased Indian datasets leading to unfair outcomes (e.g., in credit scoring, facial recognition, hiring).
#     *   **Algorithmic Fairness:** Ensuring AI systems do not discriminate against certain demographics (gender, caste, religion, socio-economic status).
#     *   Lack of transparency and explainability in AI decisions ("black box" problem).
# *   **C. Data Privacy & Security:**
#     *   **Massive Data Collection:** India's large population generates immense data, raising concerns about its collection, storage, and usage.
#     *   **Lack of Robust Data Protection Laws:** The absence of a comprehensive data protection framework (e.g., stalled Personal Data Protection Bill) leaves citizens vulnerable.
#     *   **Cybersecurity Risks:** AI systems are targets for cyberattacks, leading to data breaches and misuse.
#     *   **Surveillance Concerns:** Potential for government and corporate misuse of AI for mass surveillance without adequate oversight.
# *   **D. Digital Divide & Inequality:**
#     *   **Access Disparity:** Unequal access to technology, internet, and digital literacy between urban and rural areas.
#     *   **Exacerbating Existing Inequalities:** AI benefits might disproportionately favor the tech-savvy and urban elite, widening the gap with marginalized communities.
#     *   **Language Barrier:** Most AI development is in English, leaving out a significant portion of India's multi-lingual population.
# *   **E. Regulatory Vacuum & Governance Challenges:**
#     *   Slow pace of policy formulation compared to rapid technological advancements.
#     *   Lack of clear guidelines for AI development, deployment, and accountability.
#     *   Challenges in enforcing ethical standards and ensuring compliance.
#     *   Need for a multi-stakeholder approach to AI governance.
# *   **F. Infrastructure & Data Quality:**
#     *   Reliable high-speed internet access is still a challenge in many parts of India.
#     *   Availability of clean, structured, and diverse datasets for training robust AI models.
#     *   Energy consumption of large AI models and its environmental impact.
# *   **G. Misinformation & Malicious Use:**
#     *   The rise of deepfakes and AI-generated content for propaganda, misinformation, and defamation.
#     *   Potential for AI to be used in cyber warfare, autonomous weapons, and other harmful applications.
#
# **IV. Balancing Act: Towards a Responsible AI Future in India**
#
# *   **A. Proactive Policy & Regulatory Frameworks:**
#     *   Expediting comprehensive data protection laws.
#     *   Developing ethical AI guidelines and standards (e.g., "Responsible AI" frameworks).
#     *   Establishing regulatory bodies for AI oversight and accountability.
# *   **B. Investing in Education & Skill Development:**
#     *   Reforming education curricula to include AI literacy and critical thinking.
#     *   Massive reskilling and upskilling programs for the existing workforce.
#     *   Promoting lifelong learning and adaptability.
# *   **C. Fostering Inclusive AI Development:**
#     *   Prioritizing AI solutions for social good and addressing India's unique challenges (e.g., healthcare access, agricultural productivity).
#     *   Developing AI in vernacular languages to bridge the language barrier.
#     *   Ensuring diverse representation in AI development teams to mitigate bias.
# *   **D. Public-Private Partnerships & Collaboration:**
#     *   Encouraging collaboration between government, industry, academia, and civil society.
#     *   Sharing best practices and resources for ethical AI development.
#     *   Jointly funding research into AI safety and fairness.
# *   **E. Emphasizing Transparency & Accountability:**
#     *   Developing mechanisms for auditing AI systems for bias and fairness.
#     *   Promoting explainable AI (XAI) to understand how AI makes decisions.
#     *   Establishing clear lines of responsibility for AI-related harms.
#
# **V. Conclusion: India's AI Journey – A Path of Promise and Prudence**
#
# *   **A. Recap:** Briefly reiterate the dual nature of AI in India – immense potential for growth and transformation, coupled with significant ethical, social, and economic challenges.
# *   **B. Future Outlook:** Express optimism about India's ability to harness AI for national development, but emphasize the need for a cautious, inclusive, and ethically grounded approach.
# *   **C. Call to Action/Thought Provoker:** End with a powerful statement or question that encourages readers to engage with the topic, advocating for responsible AI development and deployment in India. (e.g., "India stands at a pivotal moment. The choices we make today in shaping our AI future will determine whether this powerful technology becomes a force for unprecedented progress or a source of deepening divides. The conversation must continue, and action must follow.")
#
# ---

# %%
print(final_state['title'])
# Out:
# Rise of AI in India and consern with AI in india
