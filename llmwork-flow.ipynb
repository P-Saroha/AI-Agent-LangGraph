# %%
from langgraph.graph import StateGraph, START, END
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict

# %%
load_dotenv()
# Out:
# True

# %%
llm = ChatGoogleGenerativeAI(
            model="gemini-2.5-flash",
            temperature=0.3
              )

# %%
class LLMState(TypedDict):

    question : str
    answer : str

# %%
def LLM_QA(state:LLMState)->LLMState:
    ## extract the question from state
    question  = state['question']

    ## from prompt 
    prompt = f'Answer the following question {question}'

    ## ask that question to LLM
    answer = llm.invoke(prompt).content

    ## update the answer in the state 
    state['answer'] = answer

    return state

# %%
## create graph 

graph = StateGraph(LLMState)

## add nodes 
graph.add_node('LLM_QA', LLM_QA)

## add edge 
graph.add_edge(START, 'LLM_QA')
graph.add_edge('LLM_QA', END)

## compile 
workflow = graph.compile()

# %%
# execute 
intial_state = {'question': 'distance between sun and moon '}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'question': 'distance between sun and moon ', 'answer': "The distance between the Sun and the Moon is **not a fixed value**; it varies significantly because the Moon orbits the Earth, and the Earth (with the Moon) orbits the Sun.\n\nTo understand this, we consider two main scenarios:\n\n1.  **When the Moon is between the Sun and Earth (New Moon phase, or during a Solar Eclipse):**\n    *   In this configuration, the Moon is closer to the Sun than the Earth is.\n    *   Approximate average Sun-Earth distance: 150 million kilometers (93 million miles)\n    *   Approximate average Earth-Moon distance: 384,400 kilometers (238,900 miles)\n    *   **Minimum distance (Sun to Moon):** Sun-Earth distance - Earth-Moon distance\n        *   150,000,000 km - 384,400 km = **~149,615,600 km** (or about 92,761,100 miles)\n\n2.  **When the Earth is between the Sun and Moon (Full Moon phase, or during a Lunar Eclipse):**\n    *   In this configuration, the Moon is further from the Sun than the Earth is.\n    *   **Maximum distance (Sun to Moon):** Sun-Earth distance + Earth-Moon distance\n        *   150,000,000 km + 384,400 km = **~150,384,400 km** (or about 93,218,900 miles)\n\n**Therefore, the distance between the Sun and the Moon ranges approximately from about 149.6 million kilometers (92.8 million miles) to 150.4 million kilometers (93.2 million miles).**\n\nIt's important to remember that these are average figures, as the Earth-Sun distance (due to Earth's elliptical orbit) and the Earth-Moon distance (due to the Moon's elliptical orbit) also vary throughout the year and month, respectively."}
